# %%
from pycorenlp import StanfordCoreNLP
import json
from nltk.tokenize import word_tokenize

nlp=StanfordCoreNLP('http://localhost:9000')

# %%
text="besides death wish coffee , how many other competitors did come?"
q=nlp.annotate(text, properties={'annotators': 'tokenize,ssplit,parse','outputFormat': 'json'})


tokens=q["sentences"][0]["tokens"]              #文の中の単語
#deps=q["sentences"][0]["basicDependencies"]     #依存関係（使わない）
parse_text=q["sentences"][0]["parse"]           #句構造のパース結果

token_list=[token["originalText"] for token in tokens]
print(token_list)
print(word_tokenize(text))


print(json.dumps(q,indent=4))
print(json.dumps(parse_text,indent=4))
print(parse_text)
# Out:
# ['besides', 'death', 'wish', 'coffee', ',', 'how', 'many', 'other', 'competitors', 'did', 'come', '?']
# ['besides', 'death', 'wish', 'coffee', ',', 'how', 'many', 'other', 'competitors', 'did', 'come', '?']
# {
#     "sentences": [
#         {
#             "index": 0,
#             "parse": "(ROOT\n  (S\n    (PP (IN besides)\n      (NP (NN death) (NN wish) (NN coffee)))\n    (, ,)\n    (SBAR\n      (WHADJP (WRB how) (JJ many))\n      (S\n        (NP (JJ other) (NNS competitors))\n        (VP (VBD did))))\n    (VP (VB come))\n    (. ?)))",
#             "basicDependencies": [
#                 {
#                     "dep": "ROOT",
#                     "governor": 0,
#                     "governorGloss": "ROOT",
#                     "dependent": 11,
#                     "dependentGloss": "come"
#                 },
#                 {
#                     "dep": "case",
#                     "governor": 4,
#                     "governorGloss": "coffee",
#                     "dependent": 1,
#                     "dependentGloss": "besides"
#                 },
#                 {
#                     "dep": "compound",
#                     "governor": 4,
#                     "governorGloss": "coffee",
#                     "dependent": 2,
#                     "dependentGloss": "death"
#                 },
#                 {
#                     "dep": "compound",
#                     "governor": 4,
#                     "governorGloss": "coffee",
#                     "dependent": 3,
#                     "dependentGloss": "wish"
#                 },
#                 {
#                     "dep": "nmod",
#                     "governor": 11,
#                     "governorGloss": "come",
#                     "dependent": 4,
#                     "dependentGloss": "coffee"
#                 },
#                 {
#                     "dep": "punct",
#                     "governor": 11,
#                     "governorGloss": "come",
#                     "dependent": 5,
#                     "dependentGloss": ","
#                 },
#                 {
#                     "dep": "advmod",
#                     "governor": 7,
#                     "governorGloss": "many",
#                     "dependent": 6,
#                     "dependentGloss": "how"
#                 },
#                 {
#                     "dep": "dep",
#                     "governor": 10,
#                     "governorGloss": "did",
#                     "dependent": 7,
#                     "dependentGloss": "many"
#                 },
#                 {
#                     "dep": "amod",
#                     "governor": 9,
#                     "governorGloss": "competitors",
#                     "dependent": 8,
#                     "dependentGloss": "other"
#                 },
#                 {
#                     "dep": "nsubj",
#                     "governor": 10,
#                     "governorGloss": "did",
#                     "dependent": 9,
#                     "dependentGloss": "competitors"
#                 },
#                 {
#                     "dep": "csubj",
#                     "governor": 11,
#                     "governorGloss": "come",
#                     "dependent": 10,
#                     "dependentGloss": "did"
#                 },
#                 {
#                     "dep": "punct",
#                     "governor": 11,
#                     "governorGloss": "come",
#                     "dependent": 12,
#                     "dependentGloss": "?"
#                 }
#             ],
#             "enhancedDependencies": [
#                 {
#                     "dep": "ROOT",
#                     "governor": 0,
#                     "governorGloss": "ROOT",
#                     "dependent": 11,
#                     "dependentGloss": "come"
#                 },
#                 {
#                     "dep": "case",
#                     "governor": 4,
#                     "governorGloss": "coffee",
#                     "dependent": 1,
#                     "dependentGloss": "besides"
#                 },
#                 {
#                     "dep": "compound",
#                     "governor": 4,
#                     "governorGloss": "coffee",
#                     "dependent": 2,
#                     "dependentGloss": "death"
#                 },
#                 {
#                     "dep": "compound",
#                     "governor": 4,
#                     "governorGloss": "coffee",
#                     "dependent": 3,
#                     "dependentGloss": "wish"
#                 },
#                 {
#                     "dep": "nmod:besides",
#                     "governor": 11,
#                     "governorGloss": "come",
#                     "dependent": 4,
#                     "dependentGloss": "coffee"
#                 },
#                 {
#                     "dep": "punct",
#                     "governor": 11,
#                     "governorGloss": "come",
#                     "dependent": 5,
#                     "dependentGloss": ","
#                 },
#                 {
#                     "dep": "advmod",
#                     "governor": 7,
#                     "governorGloss": "many",
#                     "dependent": 6,
#                     "dependentGloss": "how"
#                 },
#                 {
#                     "dep": "dep",
#                     "governor": 10,
#                     "governorGloss": "did",
#                     "dependent": 7,
#                     "dependentGloss": "many"
#                 },
#                 {
#                     "dep": "amod",
#                     "governor": 9,
#                     "governorGloss": "competitors",
#                     "dependent": 8,
#                     "dependentGloss": "other"
#                 },
#                 {
#                     "dep": "nsubj",
#                     "governor": 10,
#                     "governorGloss": "did",
#                     "dependent": 9,
#                     "dependentGloss": "competitors"
#                 },
#                 {
#                     "dep": "csubj",
#                     "governor": 11,
#                     "governorGloss": "come",
#                     "dependent": 10,
#                     "dependentGloss": "did"
#                 },
#                 {
#                     "dep": "punct",
#                     "governor": 11,
#                     "governorGloss": "come",
#                     "dependent": 12,
#                     "dependentGloss": "?"
#                 }
#             ],
#             "enhancedPlusPlusDependencies": [
#                 {
#                     "dep": "ROOT",
#                     "governor": 0,
#                     "governorGloss": "ROOT",
#                     "dependent": 11,
#                     "dependentGloss": "come"
#                 },
#                 {
#                     "dep": "case",
#                     "governor": 4,
#                     "governorGloss": "coffee",
#                     "dependent": 1,
#                     "dependentGloss": "besides"
#                 },
#                 {
#                     "dep": "compound",
#                     "governor": 4,
#                     "governorGloss": "coffee",
#                     "dependent": 2,
#                     "dependentGloss": "death"
#                 },
#                 {
#                     "dep": "compound",
#                     "governor": 4,
#                     "governorGloss": "coffee",
#                     "dependent": 3,
#                     "dependentGloss": "wish"
#                 },
#                 {
#                     "dep": "nmod:besides",
#                     "governor": 11,
#                     "governorGloss": "come",
#                     "dependent": 4,
#                     "dependentGloss": "coffee"
#                 },
#                 {
#                     "dep": "punct",
#                     "governor": 11,
#                     "governorGloss": "come",
#                     "dependent": 5,
#                     "dependentGloss": ","
#                 },
#                 {
#                     "dep": "advmod",
#                     "governor": 7,
#                     "governorGloss": "many",
#                     "dependent": 6,
#                     "dependentGloss": "how"
#                 },
#                 {
#                     "dep": "dep",
#                     "governor": 10,
#                     "governorGloss": "did",
#                     "dependent": 7,
#                     "dependentGloss": "many"
#                 },
#                 {
#                     "dep": "amod",
#                     "governor": 9,
#                     "governorGloss": "competitors",
#                     "dependent": 8,
#                     "dependentGloss": "other"
#                 },
#                 {
#                     "dep": "nsubj",
#                     "governor": 10,
#                     "governorGloss": "did",
#                     "dependent": 9,
#                     "dependentGloss": "competitors"
#                 },
#                 {
#                     "dep": "csubj",
#                     "governor": 11,
#                     "governorGloss": "come",
#                     "dependent": 10,
#                     "dependentGloss": "did"
#                 },
#                 {
#                     "dep": "punct",
#                     "governor": 11,
#                     "governorGloss": "come",
#                     "dependent": 12,
#                     "dependentGloss": "?"
#                 }
#             ],
#             "tokens": [
#                 {
#                     "index": 1,
#                     "word": "besides",
#                     "originalText": "besides",
#                     "characterOffsetBegin": 0,
#                     "characterOffsetEnd": 7,
#                     "pos": "IN",
#                     "before": "",
#                     "after": " "
#                 },
#                 {
#                     "index": 2,
#                     "word": "death",
#                     "originalText": "death",
#                     "characterOffsetBegin": 8,
#                     "characterOffsetEnd": 13,
#                     "pos": "NN",
#                     "before": " ",
#                     "after": " "
#                 },
#                 {
#                     "index": 3,
#                     "word": "wish",
#                     "originalText": "wish",
#                     "characterOffsetBegin": 14,
#                     "characterOffsetEnd": 18,
#                     "pos": "NN",
#                     "before": " ",
#                     "after": " "
#                 },
#                 {
#                     "index": 4,
#                     "word": "coffee",
#                     "originalText": "coffee",
#                     "characterOffsetBegin": 19,
#                     "characterOffsetEnd": 25,
#                     "pos": "NN",
#                     "before": " ",
#                     "after": " "
#                 },
#                 {
#                     "index": 5,
#                     "word": ",",
#                     "originalText": ",",
#                     "characterOffsetBegin": 26,
#                     "characterOffsetEnd": 27,
#                     "pos": ",",
#                     "before": " ",
#                     "after": " "
#                 },
#                 {
#                     "index": 6,
#                     "word": "how",
#                     "originalText": "how",
#                     "characterOffsetBegin": 28,
#                     "characterOffsetEnd": 31,
#                     "pos": "WRB",
#                     "before": " ",
#                     "after": " "
#                 },
#                 {
#                     "index": 7,
#                     "word": "many",
#                     "originalText": "many",
#                     "characterOffsetBegin": 32,
#                     "characterOffsetEnd": 36,
#                     "pos": "JJ",
#                     "before": " ",
#                     "after": " "
#                 },
#                 {
#                     "index": 8,
#                     "word": "other",
#                     "originalText": "other",
#                     "characterOffsetBegin": 37,
#                     "characterOffsetEnd": 42,
#                     "pos": "JJ",
#                     "before": " ",
#                     "after": " "
#                 },
#                 {
#                     "index": 9,
#                     "word": "competitors",
#                     "originalText": "competitors",
#                     "characterOffsetBegin": 43,
#                     "characterOffsetEnd": 54,
#                     "pos": "NNS",
#                     "before": " ",
#                     "after": " "
#                 },
#                 {
#                     "index": 10,
#                     "word": "did",
#                     "originalText": "did",
#                     "characterOffsetBegin": 55,
#                     "characterOffsetEnd": 58,
#                     "pos": "VBD",
#                     "before": " ",
#                     "after": " "
#                 },
#                 {
#                     "index": 11,
#                     "word": "come",
#                     "originalText": "come",
#                     "characterOffsetBegin": 59,
#                     "characterOffsetEnd": 63,
#                     "pos": "VB",
#                     "before": " ",
#                     "after": ""
#                 },
#                 {
#                     "index": 12,
#                     "word": "?",
#                     "originalText": "?",
#                     "characterOffsetBegin": 63,
#                     "characterOffsetEnd": 64,
#                     "pos": ".",
#                     "before": "",
#                     "after": ""
#                 }
#             ]
#         }
#     ]
# }
# "(ROOT\n  (S\n    (PP (IN besides)\n      (NP (NN death) (NN wish) (NN coffee)))\n    (, ,)\n    (SBAR\n      (WHADJP (WRB how) (JJ many))\n      (S\n        (NP (JJ other) (NNS competitors))\n        (VP (VBD did))))\n    (VP (VB come))\n    (. ?)))"
# (ROOT
#   (S
#     (PP (IN besides)
#       (NP (NN death) (NN wish) (NN coffee)))
#     (, ,)
#     (SBAR
#       (WHADJP (WRB how) (JJ many))
#       (S
#         (NP (JJ other) (NNS competitors))
#         (VP (VBD did))))
#     (VP (VB come))
#     (. ?)))

# %%
import json

with open("data/squad-train-v1.1.json")as f:
    data=json.load(f)
    
print(json.dumps(data["data"],indent=4)[-30000:])
# Out:
#              "text": "millet or barley"
#                             }
#                         ],
#                         "question": "What goes through a fermentation process to create tongba?",
#                         "id": "5735c7d26c16ec1900b927b3"
#                     }
#                 ]
#             },
#             {
#                 "context": "Most of the fairs and festivals in Kathmandu originated in the Malla period or earlier. Traditionally, these festivals were celebrated by Newars. In recent years, these festivals have found wider participation from other Kathmanduites as well. As the capital of the Republic of Nepal, various national festivals are celebrated in Kathmandu. With mass migration to the city, the cultures of Khas from the west, Kirats from the east, Bon/Tibetan from the north, and Mithila from the south meet in the capital and mingle harmoniously. The festivities such as the Ghode (horse) Jatra, Indra Jatra, Dashain Durga Puja festivals, Shivratri and many more are observed by all Hindu and Buddhist communities of Kathmandu with devotional fervor and enthusiasm. Social regulation in the codes enacted incorporate Hindu traditions and ethics. These were followed by the Shah kings and previous kings, as devout Hindus and protectors of Buddhist religion.",
#                 "qas": [
#                     {
#                         "answers": [
#                             {
#                                 "answer_start": 63,
#                                 "text": "Malla"
#                             }
#                         ],
#                         "question": "To what era do a majority of Kathmandu's festivals date back to?",
#                         "id": "5735c8876c16ec1900b927be"
#                     },
#                     {
#                         "answers": [
#                             {
#                                 "answer_start": 138,
#                                 "text": "Newars"
#                             }
#                         ],
#                         "question": "Before the modern era, who mostly celebrated Kathmandu festivals?",
#                         "id": "5735c8876c16ec1900b927bf"
#                     },
#                     {
#                         "answers": [
#                             {
#                                 "answer_start": 404,
#                                 "text": "west"
#                             }
#                         ],
#                         "question": "In what direction out of Kathmandu did the Khas originate from?",
#                         "id": "5735c8876c16ec1900b927c0"
#                     },
#                     {
#                         "answers": [
#                             {
#                                 "answer_start": 567,
#                                 "text": "horse"
#                             }
#                         ],
#                         "question": "What does Ghode mean?",
#                         "id": "5735c8876c16ec1900b927c1"
#                     },
#                     {
#                         "answers": [
#                             {
#                                 "answer_start": 453,
#                                 "text": "north"
#                             }
#                         ],
#                         "question": "In relation to Kathmandu, where do the Tibetans hale?",
#                         "id": "5735c8876c16ec1900b927c2"
#                     }
#                 ]
#             },
#             {
#                 "context": "The Bagmati River which flows through Kathmandu is considered a holy river both by Hindus and Buddhists, and many Hindu temples are located on the banks of this river. The importance of the Bagmati also lies in the fact that Hindus are cremated on its banks, and Kirants are buried in the hills by its side. According to the Nepali Hindu tradition, the dead body must be dipped three times into the Bagmati before cremation. The chief mourner (usually the first son) who lights the funeral pyre must take a holy riverwater bath immediately after cremation. Many relatives who join the funeral procession also take bath in the Bagmati River or sprinkle the holy water on their bodies at the end of cremation as the Bagmati is believed to purify people spiritually.",
#                 "qas": [
#                     {
#                         "answers": [
#                             {
#                                 "answer_start": 94,
#                                 "text": "Buddhists"
#                             }
#                         ],
#                         "question": "In addition to Hindus, who regards the Bagmati River as sacred?",
#                         "id": "5735c92f012e2f140011a044"
#                     },
#                     {
#                         "answers": [
#                             {
#                                 "answer_start": 236,
#                                 "text": "cremated"
#                             }
#                         ],
#                         "question": "What is done with Hindus after they die?",
#                         "id": "5735c92f012e2f140011a045"
#                     },
#                     {
#                         "answers": [
#                             {
#                                 "answer_start": 275,
#                                 "text": "buried"
#                             }
#                         ],
#                         "question": "What are done with the bodies of Kirants after death?",
#                         "id": "5735c92f012e2f140011a046"
#                     },
#                     {
#                         "answers": [
#                             {
#                                 "answer_start": 456,
#                                 "text": "first son"
#                             }
#                         ],
#                         "question": "In a Hindu funeral, who is typically the main mourner?",
#                         "id": "5735c92f012e2f140011a047"
#                     },
#                     {
#                         "answers": [
#                             {
#                                 "answer_start": 378,
#                                 "text": "three"
#                             }
#                         ],
#                         "question": "Before Hindus are cremated, how many times are their bodies placed in the Bagmati?",
#                         "id": "5735c92f012e2f140011a048"
#                     }
#                 ]
#             },
#             {
#                 "context": "Legendary Princess Bhrikuti (7th-century) and artist Araniko (1245 - 1306 AD) from that tradition of Kathmandu valley played a significant role in spreading Buddhism in Tibet and China. There are over 108 traditional monasteries (Bahals and Bahis) in Kathmandu based on Newar Buddhism. Since the 1960s, the permanent Tibetan Buddhist population of Kathmandu has risen significantly so that there are now over fifty Tibetan Buddhist monasteries in the area. Also, with the modernization of Newar Buddhism, various Theravada Bihars have been established.",
#                 "qas": [
#                     {
#                         "answers": [
#                             {
#                                 "answer_start": 29,
#                                 "text": "7th"
#                             }
#                         ],
#                         "question": "In what century was Bhrikuti said to live?",
#                         "id": "5735c9dd6c16ec1900b927d5"
#                     },
#                     {
#                         "answers": [
#                             {
#                                 "answer_start": 69,
#                                 "text": "1306"
#                             }
#                         ],
#                         "question": "When did Araniko die?",
#                         "id": "5735c9dd6c16ec1900b927d6"
#                     },
#                     {
#                         "answers": [
#                             {
#                                 "answer_start": 157,
#                                 "text": "Buddhism"
#                             }
#                         ],
#                         "question": "What religion did Araniko help to evangelize?",
#                         "id": "5735c9dd6c16ec1900b927d7"
#                     },
#                     {
#                         "answers": [
#                             {
#                                 "answer_start": 201,
#                                 "text": "108"
#                             }
#                         ],
#                         "question": "How many Newar Buddhist monasteries are present in Kathmandu?",
#                         "id": "5735c9dd6c16ec1900b927d8"
#                     },
#                     {
#                         "answers": [
#                             {
#                                 "answer_start": 409,
#                                 "text": "fifty"
#                             }
#                         ],
#                         "question": "Approximately how many monasteries in the Kathmandu area are run by Tibetan Buddhists?",
#                         "id": "5735c9dd6c16ec1900b927d9"
#                     }
#                 ]
#             },
#             {
#                 "context": "Kirant Mundhum is one of the indigenous animistic practices of Nepal. It is practiced by Kirat people. Some animistic aspects of Kirant beliefs, such as ancestor worship (worship of Ajima) are also found in Newars of Kirant origin. Ancient religious sites believed to be worshipped by ancient Kirats, such as Pashupatinath, Wanga Akash Bhairabh (Yalambar) and Ajima are now worshipped by people of all Dharmic religions in Kathmandu. Kirats who have migrated from other parts of Nepal to Kathmandu practice Mundhum in the city.",
#                 "qas": [
#                     {
#                         "answers": [
#                             {
#                                 "answer_start": 40,
#                                 "text": "animistic"
#                             }
#                         ],
#                         "question": "What type of religion is Kirant Mundhum?",
#                         "id": "5735ca406c16ec1900b927df"
#                     },
#                     {
#                         "answers": [
#                             {
#                                 "answer_start": 89,
#                                 "text": "Kirat people"
#                             }
#                         ],
#                         "question": "Who follows the Kirant Mudhum faith?",
#                         "id": "5735ca406c16ec1900b927e0"
#                     },
#                     {
#                         "answers": [
#                             {
#                                 "answer_start": 293,
#                                 "text": "Kirats"
#                             }
#                         ],
#                         "question": "Who worshipped at Wanga Akash Bhairabh in ancient times?",
#                         "id": "5735ca406c16ec1900b927e1"
#                     },
#                     {
#                         "answers": [
#                             {
#                                 "answer_start": 171,
#                                 "text": "worship of Ajima"
#                             }
#                         ],
#                         "question": "What is another name for ancestor worship?",
#                         "id": "5735ca406c16ec1900b927e2"
#                     }
#                 ]
#             },
#             {
#                 "context": "Sikhism is practiced primarily in Gurudwara at Kupundole. An earlier temple of Sikhism is also present in Kathmandu which is now defunct. Jainism is practiced by a small community. A Jain temple is present in Gyaneshwar, where Jains practice their faith. According to the records of the Spiritual Assembly of the Baha'is of Nepal, there are approximately 300 Baha'is in Kathmandu valley. They have a National Office located in Shantinagar, Baneshwor. The Baha'is also have classes for children at the National Centre and other localities in Kathmandu. Islam is practised in Kathmandu but Muslims are a minority, accounting for about 4.2% of the population of Nepal.[citation needed] It is said that in Kathmandu alone there are 170 Christian churches. Christian missionary hospitals, welfare organizations, and schools are also operating. Nepali citizens who served as soldiers in Indian and British armies, who had converted to Christianity while in service, on return to Nepal continue to practice their religion. They have contributed to the spread of Christianity and the building of churches in Nepal and in Kathmandu, in particular.",
#                 "qas": [
#                     {
#                         "answers": [
#                             {
#                                 "answer_start": 209,
#                                 "text": "Gyaneshwar"
#                             }
#                         ],
#                         "question": "Where can a temple of the Jain faith be found?",
#                         "id": "5735cc33012e2f140011a068"
#                     },
#                     {
#                         "answers": [
#                             {
#                                 "answer_start": 355,
#                                 "text": "300"
#                             }
#                         ],
#                         "question": "Kathmandu valley is home to about how many Baha'i?",
#                         "id": "5735cc33012e2f140011a069"
#                     },
#                     {
#                         "answers": [
#                             {
#                                 "answer_start": 427,
#                                 "text": "Shantinagar, Baneshwor"
#                             }
#                         ],
#                         "question": "Where is the Baha'i national office located in Nepal?",
#                         "id": "5735cc33012e2f140011a06a"
#                     },
#                     {
#                         "answers": [
#                             {
#                                 "answer_start": 633,
#                                 "text": "4.2"
#                             }
#                         ],
#                         "question": "About what percentage of the Nepali population follows Islam?",
#                         "id": "5735cc33012e2f140011a06b"
#                     },
#                     {
#                         "answers": [
#                             {
#                                 "answer_start": 728,
#                                 "text": "170"
#                             }
#                         ],
#                         "question": "About how many Christian houses of worship exist in Kathmandu?",
#                         "id": "5735cc33012e2f140011a06c"
#                     }
#                 ]
#             },
#             {
#                 "context": "Institute of Medicine, the central college of Tribhuwan University is the first medical college of Nepal and is located in Maharajgunj, Kathmandu. It was established in 1972 and started to impart medical education from 1978. A number of medical colleges including Kathmandu Medical College, Nepal Medical College, KIST Medical College, Nepal Army Institute of Health Sciences, National Academy of Medical Sciences (NAMS) and Kathmandu University School of Medical Sciences (KUSMS), are also located in or around Kathmandu.",
#                 "qas": [
#                     {
#                         "answers": [
#                             {
#                                 "answer_start": 46,
#                                 "text": "Tribhuwan"
#                             }
#                         ],
#                         "question": "Of what university is the Institute of Medicine a constituent college?",
#                         "id": "5735d0026c16ec1900b92815"
#                     },
#                     {
#                         "answers": [
#                             {
#                                 "answer_start": 123,
#                                 "text": "Maharajgunj"
#                             }
#                         ],
#                         "question": "In what part of Kathmandu is the Institute of Medicine found?",
#                         "id": "5735d0026c16ec1900b92816"
#                     },
#                     {
#                         "answers": [
#                             {
#                                 "answer_start": 219,
#                                 "text": "1978"
#                             }
#                         ],
#                         "question": "When did the Institute of Medicine begin to offer education in medicine?",
#                         "id": "5735d0026c16ec1900b92817"
#                     },
#                     {
#                         "answers": [
#                             {
#                                 "answer_start": 425,
#                                 "text": "Kathmandu University School of Medical Sciences"
#                             }
#                         ],
#                         "question": "What does KUSMS stand for?",
#                         "id": "5735d0026c16ec1900b92818"
#                     },
#                     {
#                         "answers": [
#                             {
#                                 "answer_start": 377,
#                                 "text": "National Academy of Medical Sciences"
#                             }
#                         ],
#                         "question": "What institution of tertiary education is known as NAMS?",
#                         "id": "5735d0026c16ec1900b92819"
#                     }
#                 ]
#             },
#             {
#                 "context": "Football and Cricket are the most popular sports among the younger generation in Nepal and there are several stadiums in the city. The sport is governed by the All Nepal Football Association (ANFA) from its headquarters in Kathmandu. The only international football stadium in the city is the Dasarath Rangasala Stadium, a multi-purpose stadium used mostly for football matches and cultural events, located in the neighborhood of Tripureshwor. It is the largest stadium in Nepal with a capacity of 25,000 spectators, built in 1956. Martyr's Memorial League is also held in this ground every year. The stadium was renovated with Chinese help before the 8th South Asian Games were held in Kathmandu and had floodlights installed. Kathmandu is home to the oldest football clubs of Nepal such as RCT, Sankata and NRT. Other prominent clubs include MMC, Machhindra FC, Tribhuwan Army Club (TAC) and MPC.",
#                 "qas": [
#                     {
#                         "answers": [
#                             {
#                                 "answer_start": 0,
#                                 "text": "Football"
#                             }
#                         ],
#                         "question": "Along with cricket, what sport is highly popular among Nepali youth?",
#                         "id": "5735d07d012e2f140011a087"
#                     },
#                     {
#                         "answers": [
#                             {
#                                 "answer_start": 160,
#                                 "text": "All Nepal Football Association"
#                             }
#                         ],
#                         "question": "What body oversees soccer in Nepal?",
#                         "id": "5735d07d012e2f140011a088"
#                     },
#                     {
#                         "answers": [
#                             {
#                                 "answer_start": 498,
#                                 "text": "25,000"
#                             }
#                         ],
#                         "question": "How many people can fit in Dasarath Rangasala Stadium?",
#                         "id": "5735d07d012e2f140011a089"
#                     },
#                     {
#                         "answers": [
#                             {
#                                 "answer_start": 430,
#                                 "text": "Tripureshwor"
#                             }
#                         ],
#                         "question": "In what part of Kathmandu is Dasarath Rangasala Stadium located?",
#                         "id": "5735d07d012e2f140011a08a"
#                     },
#                     {
#                         "answers": [
#                             {
#                                 "answer_start": 628,
#                                 "text": "Chinese"
#                             }
#                         ],
#                         "question": "Who assisted Nepal in renovating Dasarath Rangasala Stadium?",
#                         "id": "5735d07d012e2f140011a08b"
#                     }
#                 ]
#             },
#             {
#                 "context": "The total length of roads in Nepal is recorded to be (17,182 km (10,676 mi)), as of 2003\u201304. This fairly large network has helped the economic development of the country, particularly in the fields of agriculture, horticulture, vegetable farming, industry and also tourism. In view of the hilly terrain, transportation takes place in Kathmandu are mainly by road and air. Kathmandu is connected by the Tribhuvan Highway to the south, Prithvi Highway to the west and Araniko Highway to the north. The BP Highway, connecting Kathmandu to the eastern part of Nepal is under construction.",
#                 "qas": [
#                     {
#                         "answers": [
#                             {
#                                 "answer_start": 54,
#                                 "text": "17,182"
#                             }
#                         ],
#                         "question": "As of 2004, how many kilometers of road existed in Nepal?",
#                         "id": "5735d0f46c16ec1900b92823"
#                     },
#                     {
#                         "answers": [
#                             {
#                                 "answer_start": 289,
#                                 "text": "hilly terrain"
#                             }
#                         ],
#                         "question": "Why is travel in Kathmandu mainly via automobile or aircraft?",
#                         "id": "5735d0f46c16ec1900b92824"
#                     },
#                     {
#                         "answers": [
#                             {
#                                 "answer_start": 500,
#                                 "text": "BP"
#                             }
#                         ],
#                         "question": "What highway connecting Kathmandu to elsewhere in Nepal is currently being built?",
#                         "id": "5735d0f46c16ec1900b92825"
#                     },
#                     {
#                         "answers": [
#                             {
#                                 "answer_start": 457,
#                                 "text": "west"
#                             }
#                         ],
#                         "question": "In what direction out of Kathmandu does the Prithvi Highway travel?",
#                         "id": "5735d0f46c16ec1900b92826"
#                     },
#                     {
#                         "answers": [
#                             {
#                                 "answer_start": 466,
#                                 "text": "Araniko"
#                             }
#                         ],
#                         "question": "If one wished to travel north out of Kathmandu, what highway would be used?",
#                         "id": "5735d0f46c16ec1900b92827"
#                     }
#                 ]
#             },
#             {
#                 "context": "The main international airport serving Kathmandu and thus Nepal is the Tribhuvan International Airport, located about six kilometers (6 km (3.7 mi)) from the city centre. Operated by the Civil Aviation Authority of Nepal it has two terminals, one domestic and one international. At present, about 22 international airlines connect Nepal to other destinations in Europe, Asia and the Middle East, to cities such as Istanbul, Delhi, Kolkata, Singapore, Bangkok, Kuala Lumpur, Dhaka, Islamabad, Paro, Lhasa, Chengdu, and Guangzhou. A recent extension to the international terminal has made the distance to the airplanes shorter and in October 2009 it became possible to fly directly to Kathmandu from Amsterdam with Arkefly. Since 2013, Turkish Airlines connects Istanbul to Kathmandu. Regionally, several Nepali airlines operate from the city, including Agni Air, Buddha Air, Cosmic Air, Nepal Airlines and Yeti Airlines, to other major towns across Nepal.",
#                 "qas": [
#                     {
#                         "answers": [
#                             {
#                                 "answer_start": 71,
#                                 "text": "Tribhuvan International Airport"
#                             }
#                         ],
#                         "question": "What is Nepal's primary airport for international travel?",
#                         "id": "5735d1a86c16ec1900b92831"
#                     },
#                     {
#                         "answers": [
#                             {
#                                 "answer_start": 134,
#                                 "text": "6"
#                             }
#                         ],
#                         "question": "Starting in the center of Kathmandu, how many kilometers must one travel to reach Tribhuvan International Airport?",
#                         "id": "5735d1a86c16ec1900b92832"
#                     },
#                     {
#                         "answers": [
#                             {
#                                 "answer_start": 297,
#                                 "text": "22"
#                             }
#                         ],
#                         "question": "How many airlines use Tribhuvan International for international flights?",
#                         "id": "5735d1a86c16ec1900b92833"
#                     },
#                     {
#                         "answers": [
#                             {
#                                 "answer_start": 698,
#                                 "text": "Amsterdam"
#                             }
#                         ],
#                         "question": "From what city does Arkefly offer nonstop flights to Kathmandu?",
#                         "id": "5735d1a86c16ec1900b92834"
#                     },
#                     {
#                         "answers": [
#                             {
#                                 "answer_start": 734,
#                                 "text": "Turkish Airlines"
#                             }
#                         ],
#                         "question": "Who operates flights between Kathmandu and Istanbul?",
#                         "id": "5735d1a86c16ec1900b92835"
#                     }
#                 ]
#             },
#             {
#                 "context": "Kathmandu Metropolitan City (KMC), in order to promote international relations has established an International Relations Secretariat (IRC). KMC's first international relationship was established in 1975 with the city of Eugene, Oregon, United States. This activity has been further enhanced by establishing formal relationships with 8 other cities: Motsumoto City of Japan, Rochester of the USA, Yangon (formerly Rangoon) of Myanmar, Xi'an of the People's Republic of China, Minsk of Belarus, and Pyongyang of the Democratic Republic of Korea. KMC's constant endeavor is to enhance its interaction with SAARC countries, other International agencies and many other major cities of the world to achieve better urban management and developmental programs for Kathmandu.",
#                 "qas": [
#                     {
#                         "answers": [
#                             {
#                                 "answer_start": 229,
#                                 "text": "Oregon"
#                             }
#                         ],
#                         "question": "In what US state did Kathmandu first establish an international relationship?",
#                         "id": "5735d259012e2f140011a09d"
#                     },
#                     {
#                         "answers": [
#                             {
#                                 "answer_start": 414,
#                                 "text": "Rangoon"
#                             }
#                         ],
#                         "question": "What was Yangon previously known as?",
#                         "id": "5735d259012e2f140011a09e"
#                     },
#                     {
#                         "answers": [
#                             {
#                                 "answer_start": 476,
#                                 "text": "Minsk"
#                             }
#                         ],
#                         "question": "With what Belorussian city does Kathmandu have a relationship?",
#                         "id": "5735d259012e2f140011a09f"
#                     },
#                     {
#                         "answers": [
#                             {
#                                 "answer_start": 199,
#                                 "text": "1975"
#                             }
#                         ],
#                         "question": "In what year did Kathmandu create its initial international relationship?",
#                         "id": "5735d259012e2f140011a0a0"
#                     },
#                     {
#                         "answers": [
#                             {
#                                 "answer_start": 0,
#                                 "text": "Kathmandu Metropolitan City"
#                             }
#                         ],
#                         "question": "What is KMC an initialism of?",
#                         "id": "5735d259012e2f140011a0a1"
#                     }
#                 ]
#             }
#         ]
#     }
# ]

# %%
for topic in tqdm(data["data"]):
    topic=topic["paragraphs"]
    for paragraph in topic:
        context_text=paragraph["context"].lower()
        for qas in paragraph["qas"]:
            question_text=qas["question"].lower()
            a=qas["answers"][0]
            answer_text=a["text"].lower()
            answer_start=a["answer_start"]
            answer_end=a["answer_start"]+len(a["text"])
            if answer_start==195 and answer_end==211 and 190<=len(context_text)<=212:
                print("test")
                print(context_text)
                print(context_text[answer_start:answer_end])
                print(len(context_text))
                p_text=context_text
# Out:
# 100%|██████████| 442/442 [00:00<00:00, 3053.77it/s]
# test
#
#  sultanate of oman: muscat was the torch's only stop in the middle east, on april 14. the relay covered 20 km. no protests or incidents were reported. one of the torchbearers was syrian actress sulaf fawakherji.
# sulaf fawakherji
# 212

# %%
def sentence_tokenize(text):
    print(text)
    #テキストの一番最初に空白がある場合はインデックスがずれるのでそれの処理
    space_count=0
    while True:
        print(text[space_count])
        print("go")
        if text[space_count]==" " or text[space_count]=="\n":
            space_count+=1
        else:
            break

    q=nlp.annotate(text, properties={'annotators': 'tokenize,ssplit','outputFormat': 'json'})
    sentences=[]
    for sentence in q["sentences"]:
        tokens=sentence["tokens"]#文の中の単語
        start_id=tokens[0]["characterOffsetBegin"]+space_count
        end_id=tokens[-1]["characterOffsetEnd"]+space_count
        sentences.append((start_id,end_id))

    print(sentences)
    return sentences

# %%
def forward(text):
    q=nlp.annotate(text, properties={'annotators': 'tokenize,ssplit,parse','outputFormat': 'json'})

    tokens=q["sentences"][0]["tokens"]              #文の中の単語
    deps=q["sentences"][0]["basicDependencies"]     #依存関係（使わない）
    parse_text=q["sentences"][0]["parse"]           #句構造のパース結果

    token_list=[{"index":token["index"],"text":token["originalText"],"pos":token["pos"]} for token in tokens]
    parse_text=parse_text.replace("(","( ").replace(")"," )").split()

    WP_list=[]      #疑問詞句に含まれる単語
    NotWP_list=[]   #疑問詞句に含まれない単語
    WP_flag=False   #疑問詞句を発見済みならTrue

    depth=0
    for i in range(len(parse_text)-1):
        #depthが0の場合かつ、（疑問詞の句構造に未突入、または、すでに疑問詞が見つかっている）
        if depth==0 and ("WH" not in parse_text[i] or WP_flag==True):
            if parse_text[i]!=")" and parse_text[i+1]==")":
                NotWP_list.append(parse_text[i])
            continue
        #疑問詞の句構造の内部にいる時
        else:
            WP_flag=True
            depth=max(depth,1)
            if parse_text[i]=="(":
                depth+=1
            elif parse_text[i]==")":
                depth-=1
            if parse_text[i]!=")" and parse_text[i+1]==")":
                WP_list.append(parse_text[i])

    return WP_list,NotWP_list

# %%
Super_Bowl_50
Warsaw
Normans
Nikola_Tesla
Computational_complexity_theory
Teacher
Martin_Luther
Southern_California
Sky_(United_Kingdom)
Victoria_(Australia)
Huguenot
Steam_engine
Oxygen
1973_oil_crisis
Apollo_program
European_Union_law
Amazon_rainforest
Ctenophora
Fresno,_California
Packet_switching
Black_Death
Geology
Newcastle_upon_Tyne
Victoria_and_Albert_Museum
American_Broadcasting_Company
Genghis_Khan
Pharmacy
Immune_system
Civil_disobedience
Construction
Private_school
Harvard_University
Jacksonville,_Florida
Economic_inequality
Doctor_Who
University_of_Chicago
Yuan_dynasty
Kenya
Intergovernmental_Panel_on_Climate_Change
Chloroplast
Prime_number
Rhine
Scottish_Parliament
Islamism
Imperialism
United_Methodist_Church
French_and_Indian_War
Force
# Out:
# {'data': [1, 2]}
